# %% [markdown]
# ## Exercise - 1:
# Complete all the Task.
# 1. Read and display the image.
#
#   • Read the image using the Pillow library and display it.
#
#   • You can also use matplotlib to display the image.
#
# 2. Display only the top left corner of 100x100 pixels.
#
#   • Extract the top-left corner of the image (100x100 pixels) and display it using NumPy and
# Array Indexing.
#
# 3. Show the three color channels (R, G, B).
#
#   • Separate the image into its three color channels (Red, Green, and Blue) and display them individually, labeling each channel as R, G, and B.{Using NumPy.}
#
# 4. Modify the top 100 ×100 pixels to a value of 210 and display the resulting image:
#
#   • Modify the pixel values of the top-left 100 ×100 region to have a value of 210 (which is a light gray color), and then display the modified image.

# %%
# Mounting Google Drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Importing Necessary Libraries

from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# 1. Read and display the image.
#
#   • Read the image using the Pillow library and display it.
#
#   • You can also use matplotlib to display the image.

# %%
image_colored = Image.open("/content/drive/MyDrive/Classroom/Artificial_Intelligence/lenna_image.png")

# Image Information
print("Format", image_colored.format)
print("Mode", image_colored.mode)
print("Size", image_colored.size)
print("")

# Display the Image
display(image_colored)
# Out:
# Format PNG
# Mode RGBA
# Size (366, 357)
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=366x357>

# %% [markdown]
# 2. Display only the top left corner of 100x100 pixels.
#
#   • Extract the top-left corner of the image (100x100 pixels) and display it using NumPy and Array Indexing.

# %%
image_array = np.array(image_colored)

top_left = image_array[:100, :100]

plt.axis("off")
plt.title("Top Left Corner (100*100)")
plt.imshow(top_left)
plt.show()

# %% [markdown]
# 3. Show the three color channels (R, G, B).
#
#   • Separate the image into its three color channels (Red, Green, and Blue) and display them individually, labeling each channel as R, G, and B.{Using NumPy.}

# %%
red_channel = image_array.copy()
red_channel[:, :, 1] = 0
red_channel[:, :, 2] = 0
plt.axis("off")
plt.title("Red Channel")
plt.imshow(red_channel)
plt.show()

# %%
green_channel = image_array.copy()
green_channel[:, :, 0] = 0
green_channel[:, :, 2] = 0
plt.axis("off")
plt.title("Green Channel")
plt.imshow(green_channel)
plt.show()

# %%
blue_channel = image_array.copy()
blue_channel[:, :, 1] = 0
blue_channel[:, :, 0] = 0
plt.axis("off")
plt.title("Blue Channel")
plt.imshow(blue_channel)
plt.show()

# %% [markdown]
# 4. Modify the top 100 ×100 pixels to a value of 210 and display the resulting image:
#
#   • Modify the pixel values of the top-left 100 ×100 region to have a value of 210 (which is a light gray color), and then display the modified image.

# %%
image_modified = image_array.copy()
image_modified[:100, :100] = 210

plt.axis("off")
plt.title("Modified Image: 100 * 100 - 210")
plt.imshow(image_modified)
plt.show()

# %% [markdown]
# # Exercise - 2:
# Complete all the Task.
# 1. Load and display a grayscale image.
#
#   • Load a grayscale image using the Pillow library.
#
#   • Display the grayscale image using matplotlib.
#
# 2. Extract and display the middle section of the image (150 pixels).
#
#   • Extract a 150 pixel section from the center of the image using NumPy array slicing.
#
#   • Display this cropped image using matplotlib.
#
# 3. Apply a simple threshold to the image (e.g., set all pixel values below 100 to 0).
#
#   • Apply a threshold to the grayscale image: set all pixel values below 100 to 0, and all values above 100 to 255 (creating a binary image).
#
#   • Display the resulting binary image.
#
# 4. Rotate the image 90 degrees clockwise and display the result.
#
#   • Rotate the image by 90 degrees clockwise using the Pillow rotate method or by manipulating the image array.
#
#   • Display the rotated image using matplotlib.
#
# 5. Convert the grayscale image to an RGB image.
#
#   • Convert the grayscale image into an RGB image where the grayscale values are replicated across all three channels (R, G, and B).
#
#   • Display the converted RGB image using matplotlib.

# %% [markdown]
# 1. Load and display a grayscale image.
#
#   • Load a grayscale image using the Pillow library.
#
#   • Display the grayscale image using matplotlib.

# %%
image_colored = Image.open("/content/drive/MyDrive/Classroom/Artificial_Intelligence/camera_man.jpg").convert("L")

# Image Information
print("Format", image_colored.format)
print("Mode", image_colored.mode)
print("Size", image_colored.size)
print("")

# Display the Image
display(image_colored)
# Out:
# Format None
# Mode L
# Size (220, 325)
# <PIL.Image.Image image mode=L size=220x325>

# %% [markdown]
# 2. Extract and display the middle section of the image (150 pixels).
#
#   • Extract a 150 pixel section from the center of the image using NumPy array slicing.
#
#   • Display this cropped image using matplotlib.

# %%
image_array = np.array(image_colored)
width, height = image_array.shape

col_start = (width // 2)
row_start = (height // 2 )
mid_section = image_array[row_start:row_start+150, col_start:col_start+150]


plt.title("Center 150 * 150 pixels")
plt.axis("off")
plt.imshow(mid_section, cmap="gray")
plt.show()

# %% [markdown]
# 3. Apply a simple threshold to the image (e.g., set all pixel values below 100 to 0).
#
#   • Apply a threshold to the grayscale image: set all pixel values below 100 to 0, and all values above 100 to 255 (creating a binary image).
#
#   • Display the resulting binary image.

# %%
binary_image = np.zeros_like(image_array, dtype=np.uint8)

height, width = image_array.shape

for i in range(height):
    for j in range(width):
        if image_array[i, j] < 100:
            binary_image[i, j] = 0
        else:
            binary_image[i, j] = 255

plt.title("Thresholded Image")
plt.axis("off")
plt.imshow(binary_image, cmap="gray")
plt.show()

# %% [markdown]
# 4. Rotate the image 90 degrees clockwise and display the result.
#
#   • Rotate the image by 90 degrees clockwise using the Pillow rotate method or by manipulating the image array.
#
#   • Display the rotated image using matplotlib.

# %%
rotate_image = image_colored.rotate(-90, expand = True)

plt.title("Rotated Image (90 degree Clockwise)  ")
plt.axis("off")
plt.imshow(rotate_image, cmap="gray")
plt.show()

# %% [markdown]
# 5. Convert the grayscale image to an RGB image.
#
#   • Convert the grayscale image into an RGB image where the grayscale values are replicated across all three channels (R, G, and B).
#
#   • Display the converted RGB image using matplotlib.

# %%
image_rgb = Image.merge("RGB", (image_colored, image_colored, image_colored))

plt.title(f"Mode: {image_rgb.mode}")
plt.axis("off")
plt.imshow(image_rgb, cmap="gray")
plt.show()

# %% [markdown]
# # Exercise 3
# 1. Load and Prepare Data:
#
#   • Fetch an image of you choice.{If colour convert to grayscale}
#
#   • Center the dataset - Standaridze the Data.
#
#   • Calculate the covaraince matrix of the Standaridze data.
#
# 2. Eigen Decomposition and Identifying Principal Components:
#
#   • Compute Eigen Values and Eigen Vectors.
#
#   • Sort the eigenvalues in descending order and choose the top k eigenvectors corresponding to the highest eigenvalues.
#
#   • Identify the Principal Components with the help of cumulative Sum plot.
#
# 3. Reconstruction and Experiment:
#
#   • Reconstruction: Transform the original data by multiplying it with the selected eigenvectors(PCs) to obtain a lower-dimensional representation.
#
#   • Experiments: Pick Four different combination of principal components with various explained variance value and compare the result.
#
#   • Display the Results and Evaluate.

# %% [markdown]
# 1. Load and Prepare Data:
#
#   • Fetch an image of you choice.{If colour convert to grayscale}
#
#   • Center the dataset - Standaridze the Data.
#
#   • Calculate the covaraince matrix of the Standaridze data.

# %%
image_colored = Image.open("/content/drive/MyDrive/Classroom/Artificial_Intelligence/camera_man.jpg")
image_gray = image_colored.convert("L")

# Display the grayscale image
plt.imshow(image_gray, cmap="gray")
plt.axis("off")
plt.show()

# %%
image_array = np.array(image_gray)
height, width = image_array.shape
data = image_array.copy()

# Center the dataset - Standaridze the Data.
mean = np.mean(data, axis = 0)
centered_data = data - mean

# Calculate the covaraince matrix of the Standaridze data.
cov_matrix = np.cov(centered_data, rowvar = False)


cov_matrix.shape
# Out:
# (220, 220)

# %% [markdown]
# 2. Eigen Decomposition and Identifying Principal Components:
#
#   • Compute Eigen Values and Eigen Vectors.
#
#   • Sort the eigenvalues in descending order and choose the top k eigenvectors corresponding to the highest eigenvalues.

# %%
eigenvalues, eigenvectors = np.linalg.eigh(cov_matrix)
sorted_indices = np.argsort(eigenvalues)[::-1]
eigenvalues = eigenvalues[sorted_indices]
eigenvectors = eigenvectors[:, sorted_indices]

exp_variance_ratio = eigenvalues / np.sum(eigenvalues)
plt.plot(np.cumsum(exp_variance_ratio))
plt.title("Cumulative Explained Variance")
plt.xlabel("Number of Components")
plt.ylabel("Cumulative Expained Variance")
plt.grid(True)
plt.show()

# %% [markdown]
# 3. Reconstruction and Experiment:
#
#   • Reconstruction: Transform the original data by multiplying it with the selected eigenvectors(PCs) to obtain a lower-dimensional representation.
#
#   • Experiments: Pick Four different combination of principal components with various explained variance value and compare the result.
#
#   • Display the Results and Evaluate.

# %%
# Define components
components = [10, 20, 50, 100, 150]

# Store compressed and decompressed data
compressed = {}
decompressed = {}

# Compute compressed and decompressed versions
for k in components:
    comp = eigenvectors[:, :k]
    compressed[k] = np.dot(centered_data, comp)
    decompressed[k] = np.dot(compressed[k], comp.T) + mean

# Plot results
plt.figure(figsize=(15, 8))
plt.subplot(2, 3, 1)
plt.imshow(image_array, cmap="gray")
plt.title("Original Image")
plt.axis("off")

for i, k in enumerate(components, 2):
    plt.subplot(2, 3, i)
    plt.imshow(decompressed[k], cmap="gray")
    plt.title(f"{k} Components Image")
    plt.axis("off")

plt.tight_layout()
plt.show()
